# %%
station_graph = {"WP": ["NC"],
  "NC": ["WP","CN"],
  "CN": ["NC","PH"],
  "PH":["CN","WC"],
  "WC":["LF","PH"],
  "LF":["WC","OR"],
  "OR":["LF","RR"],
  "RR":["OR","MA"],
  "MA":["RR","AS","19"],
  "AS":["MA","BK"],
  "BK":["NB","AS"],
  "NB":["BK","EP"],
  "EP":["NB","EN"],
  "EN":["EP","RM"],
  "RM":["EN"],
  "19":["MA","12"],
  "12":["19","OW","LM"],
  "OW":["12","LM","EM"],
  "EM":["OW","MT"],
  "MT":["EM","PL"],
  "PL":["MT","CC"],
  "CC":["PL","16"],
  "16":["CC","24"],
  "24":["16","GP"],
  "GP":["BP","24"],
  "BP":["GP","DC"],
  "DC":["BP","CM"],
  "CM":["DC","SS"],
  "SS":["CM","SB"],
  "SB":["MB","SS","SO"],
  "MB":["SB"],
  "SO":["SB"],
  "LM":["12","OW","FV"],
  "FV":["LM","CL"],
  "CL":["FV","SL"],
  "SL":["CL","BF"],
  "BF":["SL","HY","CV"],
  "CV":["BF","ED"],
  "ED":["CV"],
  "HY":["BF","SH"],
  "SH":["HY","UC"],
  "UC":["SH","FM"],
  "FM":["UC"]
}

# %%
station_graph['FM']
# Out:
# ['UC']

# %%
visited = dict()
all_children = dict()

def explore(v):
    visited[v] = True
    all_children[v] = list()
    for u in station_graph[v]:
        if visited.get(u, False) is False:
            all_children[v].append(u)
            children_of_u = explore(u)
            all_children[v].extend(children_of_u)
    return all_children[v]

# %%
explore('19')
# Out:
# ['MA',
#  'RR',
#  'OR',
#  'LF',
#  'WC',
#  'PH',
#  'CN',
#  'NC',
#  'WP',
#  'AS',
#  'BK',
#  'NB',
#  'EP',
#  'EN',
#  'RM',
#  '12',
#  'OW',
#  'LM',
#  'FV',
#  'CL',
#  'SL',
#  'BF',
#  'HY',
#  'SH',
#  'UC',
#  'FM',
#  'CV',
#  'ED',
#  'EM',
#  'MT',
#  'PL',
#  'CC',
#  '16',
#  '24',
#  'GP',
#  'BP',
#  'DC',
#  'CM',
#  'SS',
#  'SB',
#  'MB',
#  'SO']

# %%
all_children['12']
# Out:
# ['OW',
#  'LM',
#  'FV',
#  'CL',
#  'SL',
#  'BF',
#  'HY',
#  'SH',
#  'UC',
#  'FM',
#  'CV',
#  'ED',
#  'EM',
#  'MT',
#  'PL',
#  'CC',
#  '16',
#  '24',
#  'GP',
#  'BP',
#  'DC',
#  'CM',
#  'SS',
#  'SB',
#  'MB',
#  'SO']

# %%
all_children
# Out:
# {'12': ['19',
#   'MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM',
#   'OW',
#   'EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO'],
#  '16': ['24', 'GP', 'BP', 'DC', 'CM', 'SS', 'SB', 'MB', 'SO'],
#  '19': ['MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM'],
#  '24': ['GP', 'BP', 'DC', 'CM', 'SS', 'SB', 'MB', 'SO'],
#  'AS': ['BK', 'NB', 'EP', 'EN', 'RM'],
#  'BF': ['SL',
#   'CL',
#   'FV',
#   'LM',
#   '12',
#   '19',
#   'MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM',
#   'OW',
#   'EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO',
#   'CV',
#   'ED'],
#  'BK': ['NB', 'EP', 'EN', 'RM'],
#  'BP': ['DC', 'CM', 'SS', 'SB', 'MB', 'SO'],
#  'CC': ['16', '24', 'GP', 'BP', 'DC', 'CM', 'SS', 'SB', 'MB', 'SO'],
#  'CL': ['FV',
#   'LM',
#   '12',
#   '19',
#   'MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM',
#   'OW',
#   'EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO'],
#  'CM': ['SS', 'SB', 'MB', 'SO'],
#  'CN': ['NC', 'WP'],
#  'CV': ['ED'],
#  'DC': ['CM', 'SS', 'SB', 'MB', 'SO'],
#  'ED': [],
#  'EM': ['MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO'],
#  'EN': ['RM'],
#  'EP': ['EN', 'RM'],
#  'FM': ['UC',
#   'SH',
#   'HY',
#   'BF',
#   'SL',
#   'CL',
#   'FV',
#   'LM',
#   '12',
#   '19',
#   'MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM',
#   'OW',
#   'EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO',
#   'CV',
#   'ED'],
#  'FV': ['LM',
#   '12',
#   '19',
#   'MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM',
#   'OW',
#   'EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO'],
#  'GP': ['BP', 'DC', 'CM', 'SS', 'SB', 'MB', 'SO'],
#  'HY': ['BF',
#   'SL',
#   'CL',
#   'FV',
#   'LM',
#   '12',
#   '19',
#   'MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM',
#   'OW',
#   'EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO',
#   'CV',
#   'ED'],
#  'LF': ['WC', 'PH', 'CN', 'NC', 'WP'],
#  'LM': ['12',
#   '19',
#   'MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM',
#   'OW',
#   'EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO'],
#  'MA': ['RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM'],
#  'MB': [],
#  'MT': ['PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO'],
#  'NB': ['EP', 'EN', 'RM'],
#  'NC': ['WP'],
#  'OR': ['LF', 'WC', 'PH', 'CN', 'NC', 'WP'],
#  'OW': ['EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO'],
#  'PH': ['CN', 'NC', 'WP'],
#  'PL': ['CC', '16', '24', 'GP', 'BP', 'DC', 'CM', 'SS', 'SB', 'MB', 'SO'],
#  'RM': [],
#  'RR': ['OR', 'LF', 'WC', 'PH', 'CN', 'NC', 'WP'],
#  'SB': ['MB', 'SO'],
#  'SH': ['HY',
#   'BF',
#   'SL',
#   'CL',
#   'FV',
#   'LM',
#   '12',
#   '19',
#   'MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM',
#   'OW',
#   'EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO',
#   'CV',
#   'ED'],
#  'SL': ['CL',
#   'FV',
#   'LM',
#   '12',
#   '19',
#   'MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM',
#   'OW',
#   'EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO'],
#  'SO': [],
#  'SS': ['SB', 'MB', 'SO'],
#  'UC': ['SH',
#   'HY',
#   'BF',
#   'SL',
#   'CL',
#   'FV',
#   'LM',
#   '12',
#   '19',
#   'MA',
#   'RR',
#   'OR',
#   'LF',
#   'WC',
#   'PH',
#   'CN',
#   'NC',
#   'WP',
#   'AS',
#   'BK',
#   'NB',
#   'EP',
#   'EN',
#   'RM',
#   'OW',
#   'EM',
#   'MT',
#   'PL',
#   'CC',
#   '16',
#   '24',
#   'GP',
#   'BP',
#   'DC',
#   'CM',
#   'SS',
#   'SB',
#   'MB',
#   'SO',
#   'CV',
#   'ED'],
#  'WC': ['PH', 'CN', 'NC', 'WP'],
#  'WP': []}
